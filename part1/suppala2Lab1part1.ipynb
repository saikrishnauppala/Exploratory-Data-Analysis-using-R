# %% [markdown]
# # problem 1

# %%
#sales1 vector
sales1=c(12,14,16,29,30,45,19,20,16, 19, 34, 20)
sales2=rpois(12,34)
par(bg="cornsilk")
#plotting sales data
plot(sales1, col="blue", type="o", ylim=c(0,100), xlab="Month", ylab="Sales" )
title(main="Sales by Month")
lines(sales2, type="o", pch=22, lty=2, col="red")
grid(nx=NA, ny=NULL)
legend("topright", inset=.05, c("Sales1","Sales2"), fill=c("blue","red"), horiz=TRUE)#legend forsales1 &2
# Out:
# Plot with title "Sales by Month"

# %% [markdown]
# # problem 2

# %%
sales<-read.table(file.choose(), header=T)#choose All data/sales.txt
sales  # to verify that data has been read
# Out:
#    Sales1 Sales2
# 1  34     45
# 2  23     23
# 3  12     56
# 4  29     34
# 5  34     45
# 6  34     56
# 7  12     89
# 8  80     36
# 9  80     44
# 10 56     66
# 11 55     60
# 12 45     23

# %%
barplot(as.matrix(sales), main="Sales Data", ylab= "Total",beside=T, col=rainbow(5))
#comparing sales 1 and sales 2
# Out:
# Plot with title "Sales Data"

# %% [markdown]
# # problem 3

# %%
fn<-boxplot(sales,col=c("orange","green"))$stats#box plot for sales datset
text(1.45, fn[3,2], paste("Median =", fn[3,2]), adj=0, cex=.7)
text(0.45, fn[3,1],paste("Median =", fn[3,1]), adj=0, cex=.7)
grid(nx=NA, ny=NULL)
# Out:
# plot without title

# %% [markdown]
# # problem 4

# %%
#plotting facebook and apple data...All data/FB.csv and AAPL.csv
fb1<-read.csv(file.choose())
aapl1<-read.csv(file.choose())
par(bg="cornsilk")
plot(aapl1$Adj.Close, col="blue", type="o", ylim=c(140,200), xlab="Days", ylab="Price" )
lines(fb1$Adj.Close, type="o", pch=22, lty=2, col="red")
legend("topright", inset=.05, c("Apple","Facebook"), fill=c("blue","red"), horiz=TRUE)
#Just study the distribution of the adjusted close of the stock price of Apple.
hist(aapl1$Adj.Close, col=rainbow(8))
# Out:
# plot without title
# Plot with title "Histogram of aapl1$Adj.Close"

# %% [markdown]
# # Problem 5

# %%
data()

# %%
library(ggplot2)  #importing ggplot for mpg dataset
attach(mpg)#attaching dataset to local
head(mpg)
summary(mpg)
#after analysis remove the data from the memory
detach(mpg)#detaching
# Out:
#   manufacturer model displ year cyl trans      drv cty hwy fl class
# 1 audi         a4    1.8   1999 4   auto(l5)   f   18  29  p  compact
# 2 audi         a4    1.8   1999 4   manual(m5) f   21  29  p  compact
# 3 audi         a4    2.0   2008 4   manual(m6) f   20  31  p  compact
# 4 audi         a4    2.0   2008 4   auto(av)   f   21  30  p  compact
# 5 audi         a4    2.8   1999 6   auto(l5)   f   16  26  p  compact
# 6 audi         a4    2.8   1999 6   manual(m5) f   18  26  p  compact
#  manufacturer          model               displ            year
#  Length:234         Length:234         Min.   :1.600   Min.   :1999
#  Class :character   Class :character   1st Qu.:2.400   1st Qu.:1999
#  Mode  :character   Mode  :character   Median :3.300   Median :2004
#                                        Mean   :3.472   Mean   :2004
#                                        3rd Qu.:4.600   3rd Qu.:2008
#                                        Max.   :7.000   Max.   :2008
#       cyl           trans               drv                 cty
#  Min.   :4.000   Length:234         Length:234         Min.   : 9.00
#  1st Qu.:4.000   Class :character   Class :character   1st Qu.:14.00
#  Median :6.000   Mode  :character   Mode  :character   Median :17.00
#  Mean   :5.889                                         Mean   :16.86
#  3rd Qu.:8.000                                         3rd Qu.:19.00
#  Max.   :8.000                                         Max.   :35.00
#       hwy             fl               class
#  Min.   :12.00   Length:234         Length:234
#  1st Qu.:18.00   Class :character   Class :character
#  Median :24.00   Mode  :character   Mode  :character
#  Mean   :23.44
#  3rd Qu.:27.00
#  Max.   :44.00

# %%
library(help=datasets)
library(datasets)
head(uspop)
plot(uspop)
# Out:
# [1]  3.93  5.31  7.24  9.64 12.90 17.10
# plot without title

# %% [markdown]
# # Problem 6

# %%
install.packages("maptools", repos='http://cran.us.r-project.org')#installing  ggmap,maptools and rcul package
install.packages("ggmap")
# Out:
# Warning message:
# "package 'maptools' is in use and will not be installed"also installing the dependencies 'proto', 'mapproj', 'geosphere'
#
# Warning message:
# "unable to access index for repository http://www.stats.ox.ac.uk/pub/RWin/bin/windows/contrib/3.5:
#   cannot open URL 'http://www.stats.ox.ac.uk/pub/RWin/bin/windows/contrib/3.5/PACKAGES'"Warning message:
# "package 'ggmap' is in use and will not be installed"
# package 'proto' successfully unpacked and MD5 sums checked
# package 'mapproj' successfully unpacked and MD5 sums checked
# package 'geosphere' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\saikr\AppData\Local\Temp\RtmpcrRPN9\downloaded_packages

# %%
library("ggmap")
library("maptools")
library(maps)
register_google(key = "AIzaSyAA4aNFh4DZX9qjJiUbN5bS6dEWK8gnHeE")

# %%
visited <- c("SFO", "Chennai", "London", "Melbourne", "Johannesbury, SA")
ll.visited <- geocode(visited)
visit.x <- ll.visited$lon
visit.y <- ll.visited$lat
map("world", fill=TRUE, col="white", bg="lightblue", ylim=c(-60, 90), mar=c(0,0,0,0))
points(visit.x,visit.y, col="red", pch=36)
# Out:
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=SFO&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Chennai&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=London&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Melbourne&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Johannesbury,+SA&key=xxx
# plot without title

# %%
library("ggmap")
library("maptools")
library(maps)
visited <- c("SFO", "New York", "Buffalo", "Dallas, TX")
ll.visited <- geocode(visited)#geocoding cities
visit.x <- ll.visited$lon
visit.y <- ll.visited$lat
map("state", fill=TRUE, col=rainbow(50), bg="cornsilk", mar=c(0,0,0,0))#plotting in map
points(visit.x,visit.y, col="white", pch=36)
# Out:
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=SFO&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=New+York&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Buffalo&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Dallas,+TX&key=xxx
# plot without title

# %% [markdown]
# # Problem 7

# %%
attach(mtcars)
head(mtcars)
plot(mtcars[c(1,3,4,5,6)], main="MTCARS Data")
plot(mtcars[c(1,3,4,6)], main="MTCARS Data")
plot(mtcars[c(1,3,4,6)], col=rainbow(5),main="MTCARS Data")
detach(mtcars)
# Out:
# The following object is masked from package:ggplot2:
#
#     mpg
#                   mpg  cyl disp hp  drat wt    qsec  vs am gear carb
# Mazda RX4         21.0 6   160  110 3.90 2.620 16.46 0  1  4    4
# Mazda RX4 Wag     21.0 6   160  110 3.90 2.875 17.02 0  1  4    4
# Datsun 710        22.8 4   108   93 3.85 2.320 18.61 1  1  4    1
# Hornet 4 Drive    21.4 6   258  110 3.08 3.215 19.44 1  0  3    1
# Hornet Sportabout 18.7 8   360  175 3.15 3.440 17.02 0  0  3    2
# Valiant           18.1 6   225  105 2.76 3.460 20.22 1  0  3    1
# plot without title
# plot without title
# plot without title

# %% [markdown]
# # Exploring  Carbon dioxide dataset(CO2)

# %%
attach(CO2)
head(CO2)
plot(CO2[c(1,2,3,4,5)], main="CO2 Data")
plot(CO2[c(1,2,3,4)], main="CO2 Data")
plot(CO2[c(1,3,4)], col=rainbow(5),main="CO2 Data")
detach(CO2)
# Out:
# The following objects are masked from CO2 (pos = 3):
#
#     conc, Plant, Treatment, Type, uptake
#
# The following objects are masked from CO2 (pos = 4):
#
#     conc, Plant, Treatment, Type, uptake
#
# The following objects are masked from CO2 (pos = 5):
#
#     conc, Plant, Treatment, Type, uptake
#   Plant Type   Treatment  conc uptake
# 1 Qn1   Quebec nonchilled  95  16.0
# 2 Qn1   Quebec nonchilled 175  30.4
# 3 Qn1   Quebec nonchilled 250  34.8
# 4 Qn1   Quebec nonchilled 350  37.2
# 5 Qn1   Quebec nonchilled 500  35.3
# 6 Qn1   Quebec nonchilled 675  39.2
# plot without title
# plot without title
# plot without title

# %% [markdown]
# # Problem 8

# %%
library(ggplot2)
ggplot(mtcars, aes(x=mpg, y=disp)) + geom_point()
# Out:
# plot without title
